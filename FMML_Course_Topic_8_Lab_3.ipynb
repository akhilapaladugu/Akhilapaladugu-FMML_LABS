# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-08 07:03:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  77.6MB/s    in 0.9s
#
# 2024-04-08 07:03:50 (77.6 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18820   1208.3809v2  Various methods for lifted probabilistic infer...    cs
# 22614  1702.08402v2  We introduce a novel kernel that models input-...  stat
# 4330    1409.4327v2  In principle, zero-shot learning makes it poss...    cs
# 31423  1803.03415v2  The clothing fashion reflects the common aesth...    cs
# 34754  1801.01884v2  Neural embeddings are a popular set of methods...    cs
# ...             ...                                                ...   ...
# 7996   1710.08266v1  In this paper, we propose deep learning archit...  stat
# 22777  1706.05612v2  The two-sample hypothesis testing problem is s...  stat
# 18569   1106.0237v1  Pearl and Dechter (1996) claimed that the d-se...    cs
# 30966  1801.10442v1  The goal of this paper is the automatic identi...    cs
# 40527   1301.2785v1  Document classification is a task of assigning...    cs
#
#                                                    title  year  \
# 18820  Lifted Variable Elimination: A Novel Operator ...  2012
# 22614  A Mutually-Dependent Hadamard Kernel for Model...  2017
# 4330    Zero Shot Recognition with Unreliable Attributes  2014
# 31423  Fusing Hierarchical Convolutional Features for...  2018
# 34754  Unsupervised Low-Dimensional Vector Representa...  2018
# ...                                                  ...   ...
# 7996   Deep Learning applied to Road Traffic Speed fo...  2017
# 22777  Kernel Two-Sample Hypothesis Testing Using Ker...  2017
# 18569  On Deducing Conditional Independence from d-Se...  2011
# 30966  From Benedict Cumberbatch to Sherlock Holmes: ...  2018
# 40527  A comparison of SVM and RVM for Document Class...  2013
#
#                                                 keywords
# 18820  [probabilistic, inference, understanding, rela...
# 22614  [introduce, dependent, couplings, processes, c...
# 4330   [principle, recognition, specifying, categorys...
# 31423  [aesthetics, recognize, meaningful, individual...
# 34754  [embeddings, representing, dimensional, diffic...
# ...                                                  ...
# 7996   [architectures, regression, dependent, algorit...
# 22777  [hypothesis, challenging, dimensional, hypothe...
# 18569  [separation, criterion, conditional, independe...
# 30966  [automatic, identification, characters, approa...
# 40527  [classification, assigning, unclassified, pred...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18820    [probabilistic, inference, understanding, rela...
# 22614    [introduce, dependent, couplings, processes, c...
# 4330     [principle, recognition, specifying, categorys...
# 31423    [aesthetics, recognize, meaningful, individual...
# 34754    [embeddings, representing, dimensional, diffic...
#                                ...
# 40946    [convergence, stochastic, optimization, functi...
# 20294    [electronic, cyberathletes, different, recogni...
# 14490    [different, estimating, statistical, statistic...
# 25522    [localization, experience, constitutes, locali...
# 7263     [universal, functions, parametrization, semide...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8740 words.
# Out of those 4571 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee2fe789-b249-4649-ac22-4d03d9bf0577" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee2fe789-b249-4649-ac22-4d03d9bf0577")) {                    Plotly.newPlot(                        "ee2fe789-b249-4649-ac22-4d03d9bf0577",                        [{"x":["inference","understanding","propositional","theoretical","contributions","relationships","characterization","elimination","introduce","completeness","augmented","inversion","probabilistic","counterparts","simultaneously","modelling","correlations","covariances","observation","performance","correlation","classification","different","stationary","variational","components","highlight","dependent","covariance","processes","couplings","achieving","recognition","specifying","attributes","possesses","statistics","classifiers","explicitly","classifier","descriptions","unreliable","leveraging","extensions","principle","enumerating","properties","demonstrate","predictions","construct","providing","attribute","discriminative","categories","background","experiments","collected","continuous","assumption","evaluation","convolutional","specifically","aesthetics","individual","hierarchical","effectiveness","meaningful","influence","recognize","performed","segmentation","segmented","correlated","hyperparameters","representations","occurrence","similarity","correlate","relatedness","implementations","transparent","difficult","depending","abstracts","outperform","benchmarks","representing","embeddings","representation","according","dimensions","complementary","interpret","parameters","including","biomedical","inspection","importance","abbreviations","extensive","dimensional","partially","available","judgement","unsupervised","interfaces","comprehensive","expressions","evaluated","hypothesize","appearance","expression","reasoning","alignment","generalization","occlusions","generated","deformable","excellent","comprises","significant","resulting","constrained","independent","responses","discretized","hypotheses","occlusion","variations","unoccluded","respectively","particular","electricity","literature","sequences","adaptation","improvements","forecasting","aggregation","sequential","arbitrary","concerned","aggregating","specialized","specialist","empirical","prediction","methodology","introduced","consumption","experimental","brightness","structure","correction","previously","qualitative","modulated","enhancement","efficient","universal","distribution","alleviated","distorted","deficiencies","attenuate","distortion","consistently","parameter","quantitative","cumulative","truncated","scenarios","algorithm","sensitivity","contribution","suitability","simulated","investigate","practical","selection","detectability","searching","discriminability","conditions","perspectives","environment","application","compression","complicated","dictionary","identifies","principal","denoising","inpainting","successful","completion","synthetic","parameterization","reconstructing","applications"],"y":[211,165,29,158,49,66,31,8,335,9,37,10,134,27,109,46,24,3,62,902,72,528,768,28,50,103,31,64,24,100,0,93,366,10,57,6,58,115,70,148,31,14,48,42,58,3,233,534,74,88,86,40,105,74,76,626,79,95,66,264,395,196,7,114,107,200,55,66,38,129,224,27,36,15,224,22,180,7,10,37,8,161,30,6,97,98,94,74,377,88,53,35,19,234,247,20,5,97,6,193,176,54,289,2,137,9,59,37,140,10,71,55,142,52,113,21,170,17,27,25,250,146,60,122,38,5,21,29,91,2,75,297,8,137,90,60,117,13,31,82,91,18,17,24,0,157,234,74,142,26,390,5,368,32,106,59,4,31,395,46,191,5,10,7,5,24,38,129,74,14,4,99,797,39,73,7,60,162,141,151,1,39,4,149,20,109,240,41,35,47,25,33,40,15,97,30,137,10,16,421],"type":"bar"},{"x":["inference","understanding","propositional","theoretical","con ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4571,), (4571, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>What</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Objective</span> <span style=''>Does</span> <span style=''>Self</span> <span style=''>paced</span> <span style=''>Learning</span> <span style=''>Indeed</span> <span style=''>Optimize</span> <br/><br/><span style=''>Self</span> <span style=''>paced</span> <span style=''>learning</span> <span style=''>(SPL)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>recently</span> <span style=''>raised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>designed</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulating</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>humansanimals</span> <span style=''>A</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>SPL</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>realization</span> <span style=''>schemes</span> <span style=''>have</span> <span style=''>been</span> <span style=''>designed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.34855136084284455);'>different</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.6123348017621144);'>recognition</span> <span style=''>tasks</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>substantiated</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3112244897959184);'>effective</span> <span style=''>in</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363636);'>investigation</span> <span style=''>on</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3008849557522124);'>theoretical</span> <span style=''>insight</span> <span style=''>is</span> <span style=''>still</span> <span style=''>a</span> <span style=''>blank</span> <span style=''>To</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>this</span> <span style=''>study</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>some</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3008849557522124);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695654);'>understanding</span> <span style=''>under</span> <span style=''>the</span> <span style=''>SPL</span> <span style=''>scheme</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>the</span> <span style=''>solving</span> <span style=''>strategy</span> <span style=''>on</span> <span style=''>SPL</span> <span style=''>accords</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>majorization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.43209876543209874);'>implemented</span> <span style=''>on</span> <span style=''>a</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>find</span> <span style=''>that</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Concentration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimiser</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concentration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>for</span> <span style=''>the</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>estimate</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizers</span> <span style=''>In</span> <span style=''>the</span> <span style=''>general</span> <span style=''>setting</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>sanity</span> <span style=''>check</span> <span style=''>bounds</span> <span style=''>in</span> <span style=''>the</span> <span style=''>spirit</span> <span style=''>of</span> <span style=''>citeKR99</span> <span style=''>textquotedbllefttextitbounds</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>error</span> <span style=''>of</span> <span style=''>this</span> <span style=''>estimate</span> <span style=''>is</span> <span style=''>not</span> <span style=''>much</span> <span style=''>worse</span> <span style=''>that</span> <span style=''>of</span> <span style=''>training</span> <span style=''>error</span> <span style=''>estimate</span> <span style=''>textquotedblright</span> <span style=''>General</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>with</span> <span style=''>finite</span> <span style=''>VC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>We</span> <span style=''>closely</span> <span style=''>follow</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>citeDUD03</span> <span style=''>to</span> <span style=''>cover</span> <span style=''>a</span> <span style=''>large</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>leave</span> <span style=''>one</span> <span style=''>out</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>k</span> <span style=''>fold</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>hold</span> <span style=''>out</span> <span style=''>cross</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style=''>Mean</span> <span style=''>Field</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5918367346938775);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.31270358306188933);'>Inference</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exponential</span> <span style=''>Families</span> <br/><br/><span style=''>The</span> <span style=''>mean</span> <span style=''>field</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>entail</span> <span style='background-color:rgba(255, 0, 0, 0.3076923076923077);'>approximating</span> <span style='background-color:rgba(255, 0, 0, 0.3055555555555556);'>intractable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3628318584070797);'>distributions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variationally</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3628318584070797);'>distributions</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractable</span> <span style=''>family</span> <span style=''>enjoy</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guaranteed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>true</span> <span style='background-color:rgba(255, 0, 0, 0.5303643724696356);'>likelihood</span> <span style=''>But</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirement</span> <span style=''>for</span> <span style=''>model</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>and</span> <span style=''>unclear</span> <span style='background-color:rgba(255, 0, 0, 0.31270358306188933);'>inference</span> <span style=''>quality</span> <span style=''>in</span> <span style=''>various</span> <span style=''>models</span> <span style=''>it</span> <span style=''>is</span> <span style=''>not</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>as</span> <span style=''>a</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.31270358306188933);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>mean</span> <span style=''>field</span> <span style=''>theory</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.5918367346938775);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3055555555555556);'>intractable</span> <span style='background-color:rgba(255, 0, 0, 0.3628318584070797);'>distributions</span> <span style=''>using</span> <span style=''>a</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Avoiding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discrimination</span> <span style=''>through</span> <span style=''>Causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reasoning</span> <br/><br/><span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>fairness</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrimination</span> <span style=''>criteria</span> <span style=''>and</span> <span style=''>how</span> <span style=''>they</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>Most</span> <span style=''>of</span> <span style=''>these</span> <span style=''>criteria</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>They</span> <span style=''>depend</span> <span style=''>only</span> <span style=''>on</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>protected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attribute</span> <span style=''>features</span> <span style=''>and</span> <span style=''>outcome</span> <span style=''>While</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convenient</span> <span style=''>to</span> <span style=''>work</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>criteria</span> <span style=''>have</span> <span style=''>severe</span> <span style=''>inherent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>that</span> <span style=''>prevent</span> <span style=''>them</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resolving</span> <span style=''>matters</span> <span style=''>of</span> <span style=''>fairness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conclusively</span> <span style=''>Going</span> <span style=''>beyond</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>criteria</span> <span style=''>we</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrimination</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>protected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>language</span> <span style=''>of</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reasoning</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>shifts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>from</span> <span style=''>What</span> <span style=''>is</span> <span style=''>the</span> <span style=''>right</span> <span style=''>fairness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style=''>What</span> <span style=''>do</span> <span style=''>we</span> <span style=''>want</span> <span style=''>to</span> <span style=''>assume</span> <span style=''>about</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>proce ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1340682788051209)
# 	detection (0.11522048364153627)
# 	knowledge (0.13122332859174965)
# 	information (0.25675675675675674)
# 	segmentation (0.07965860597439545)
# 	architecture (0.09423897581792319)
# 	challenging (0.11557610241820768)
# 	recognition (0.1301564722617354)
# 	different (0.27311522048364156)
# 	convolutional (0.14046941678520625)
#
# Some Statistics words are:
# 	statistical (0.15040241448692154)
# 	stochastic (0.1358148893360161)
# 	theoretical (0.14788732394366197)
# 	estimation (0.1664989939637827)
# 	variables (0.1488933601609658)
# 	algorithm (0.39889336016096577)
# 	distribution (0.1841046277665996)
# 	dimensional (0.1790744466800805)
# 	inference (0.20271629778672032)
# 	regression (0.1891348088531187)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e80f55f-c92a-4b6b-8811-e007f0306401" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e80f55f-c92a-4b6b-8811-e007f0306401")) {                    Plotly.newPlot(                        "9e80f55f-c92a-4b6b-8811-e007f0306401",                        [{"x":["inference","understanding","propositional","theoretical","contributions","relationships","characterization","elimination","introduce","completeness","augmented","inversion","probabilistic","counterparts","simultaneously","modelling","correlations","covariances","observation","performance","correlation","classification","different","stationary","variational","components","highlight","dependent","covariance","processes","couplings","achieving","recognition","specifying","attributes","possesses","statistics","classifiers","explicitly","classifier","descriptions","unreliable","leveraging","extensions","principle","enumerating","properties","demonstrate","predictions","construct","providing","attribute","discriminative","categories","background","experiments","collected","continuous","assumption","evaluation","convolutional","specifically","aesthetics","individual","hierarchical","effectiveness","meaningful","influence","recognize","performed","segmentation","segmented","correlated","hyperparameters","representations","occurrence","similarity","correlate","relatedness","implementations","transparent","difficult","depending","abstracts","outperform","benchmarks","representing","embeddings","representation","according","dimensions","complementary","interpret","parameters","including","biomedical","inspection","importance","abbreviations","extensive","dimensional","partially","available","judgement","unsupervised","interfaces","comprehensive","expressions","evaluated","hypothesize","appearance","expression","reasoning","alignment","generalization","occlusions","generated","deformable","excellent","comprises","significant","resulting","constrained","independent","responses","discretized","hypotheses","occlusion","variations","unoccluded","respectively","particular","electricity","literature","sequences","adaptation","improvements","forecasting","aggregation","sequential","arbitrary","concerned","aggregating","specialized","specialist","empirical","prediction","methodology","introduced","consumption","experimental","brightness","structure","correction","previously","qualitative","modulated","enhancement","efficient","universal","distribution","alleviated","distorted","deficiencies","attenuate","distortion","consistently","parameter","quantitative","cumulative","truncated","scenarios","algorithm","sensitivity","contribution","suitability","simulated","investigate","practical","selection","detectability","searching","discriminability","conditions","perspectives","environment","application","compression","complicated","dictionary","identifies","principal","denoising","inpainting","successful","completion","synthetic","parameterization","reconstructing","applications","reconstruction","determined","moderately","relatively","transformer","functions","independently","statistical","geometric","normalisation","spatially","uncontrolled","localisation","transform","extension","construction","estimating","transitions","emissions","inferring","motivated","favorable","interpretability","revolution","annealing","published","algorithms","attractive","addressed","expectation","computational","maximization","supervised","trainable","footprint","conventional","deterministic","projections","multiplications","structures","projection","evaluations","parallelization","expensive","implement","excessive","approaches","additional","redundancy","computations","technique","candidate","partitioning","rec ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	couplings
# 	specialist
# 	exploding
# 	multiplayer
# 	functoriality
# 	oscillates
# 	tibshirani
# 	davenport
# 	scientist
# 	capitalization
# 	parallelize
# 	heckerman
# 	fluctuation
# 	robustification
# 	counterexample
# 	climatology
# 	sparsifying
# 	integrable
# 	bernsteins
# 	looseness
# Some words which never appear in Statistics papers:
# 	propositional
# 	abbreviations
# 	judgement
# 	occlusions
# 	unoccluded
# 	attenuate
# 	discriminability
# 	transformer
# 	credibility
# 	fingerprint
# 	reflection
# 	interoperability
# 	dempsters
# 	propositions
# 	evidences
# 	descriptive
# 	scanpaths
# 	fixations
# 	orientations
# 	shapelets

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0589458872472546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
